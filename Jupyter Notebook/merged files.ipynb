# %%
import numpy as np
phone = pd.read_csv('samsung.csv')
phone.head()
# Out:
#                                            Image_Url  \
# 0  https://m.media-amazon.com/images/I/41UuyU7HsP...
# 1  https://m.media-amazon.com/images/I/41UuyU7HsP...
# 2  https://m.media-amazon.com/images/I/41UuyU7HsP...
# 3  https://m.media-amazon.com/images/I/41UuyU7HsP...
# 4  https://m.media-amazon.com/images/I/41UuyU7HsP...
#
#                                            Item_Name      Username  \
# 0  Samsung Galaxy S20 FE 5G | Factory Unlocked An...      Leonardo
# 1  Samsung Galaxy S20 FE 5G | Factory Unlocked An...       Jacob E
# 2  Samsung Galaxy S20 FE 5G | Factory Unlocked An...  Angel Chavez
# 3  Samsung Galaxy S20 FE 5G | Factory Unlocked An...         Shawn
# 4  Samsung Galaxy S20 FE 5G | Factory Unlocked An...     Morgan J.
#
#    Rating_Score                                 Review_Description  \
# 0             5  Tengo prácticamente una semana con el equipo y...
# 1             3  Coming from a pixel 2 I expected more.Front ca...
# ...

# %%
phone2 = pd.read_csv('UMIDIGI.csv')
phone2.head()
# Out:
#                                            Image_Url  \
# 0  https://m.media-amazon.com/images/I/419sppTfYE...
# 1  https://m.media-amazon.com/images/I/419sppTfYE...
# 2  https://m.media-amazon.com/images/I/419sppTfYE...
# 3  https://m.media-amazon.com/images/I/419sppTfYE...
# 4  https://m.media-amazon.com/images/I/419sppTfYE...
#
#                                            Item_Name   Username  Rating_Score  \
# 0  UMIDIGI A5 Pro Unlocked Mobile Phones SIM Free...    Kareem              4
# 1  UMIDIGI A5 Pro Unlocked Mobile Phones SIM Free...      Amber             4
# 2  UMIDIGI A5 Pro Unlocked Mobile Phones SIM Free...      Jamie             4
# 3  UMIDIGI A5 Pro Unlocked Mobile Phones SIM Free...    Raymond             5
# 4  UMIDIGI A5 Pro Unlocked Mobile Phones SIM Free...  Nightmare             5
#
#                                   Review_Description  \
# 0  Ok' let's get down to the nitty-gritty here. I...
# 1  First off' I wanna say that the whole shipping...
# ...

# %%
out = phone.append(phone2)
out
# Out:
#                                             Image_Url  \
# 0   https://m.media-amazon.com/images/I/41UuyU7HsP...
# 1   https://m.media-amazon.com/images/I/41UuyU7HsP...
# 2   https://m.media-amazon.com/images/I/41UuyU7HsP...
# 3   https://m.media-amazon.com/images/I/41UuyU7HsP...
# 4   https://m.media-amazon.com/images/I/41UuyU7HsP...
# ..                                                ...
# 68  https://m.media-amazon.com/images/I/419sppTfYE...
# 69  https://m.media-amazon.com/images/I/419sppTfYE...
# 70  https://m.media-amazon.com/images/I/419sppTfYE...
# 71  https://m.media-amazon.com/images/I/419sppTfYE...
# 72  https://m.media-amazon.com/images/I/419sppTfYE...
#
#                                             Item_Name            Username  \
# 0   Samsung Galaxy S20 FE 5G | Factory Unlocked An...            Leonardo
# 1   Samsung Galaxy S20 FE 5G | Factory Unlocked An...             Jacob E
# 2   Samsung Galaxy S20 FE 5G | Factory Unlocked An...        Angel Chavez
# ...

# %%
print(out.isnull().sum())
# Out:
# Image_Url             0
# Item_Name             0
# Username              0
# Rating_Score          0
# Review_Description    1
# Review_Date           0
# dtype: int64

# %%
out.to_csv('merged.csv',index=False)
